# %% [markdown]
# ### **import necessary libraries**

# %%
import pandas as pd
import requests

# %% [markdown]
# ### **load base dataset**

# %%
df=pd.read_csv("billboard 2020-2025.csv")

# %%
df
# Out:
#       chart_week  current_week                              title  \
# 0       1/4/2020             1    All I Want For Christmas Is You
# 1       1/4/2020             2  Rockin' Around The Christmas Tree
# 2       1/4/2020             3                   Jingle Bell Rock
# 3       1/4/2020             4            A Holly Jolly Christmas
# 4       1/4/2020             5                            Circles
# ...          ...           ...                                ...
# 27695  1/11/2025            96                        Holy Smokes
# 27696  1/11/2025            97                          High Road
# 27697  1/11/2025            98                     On One Tonight
# 27698  1/11/2025            99                         St. Chroma
# 27699  1/11/2025           100                       Cowboy Songs
#
#                                         performer last_week  peak_pos  \
# 0                                    Mariah Carey         1         1
# ...

# %% [markdown]
# ### evaluate dataset using basic pandas functions

# %%
df.isna().mean()*100
# Out:
# chart_week       0.000000
# current_week     0.000000
# title            0.000000
# performer        0.000000
# last_week        6.555957
# peak_pos         0.000000
# wks_on_chart     0.000000
# genre(s)        99.956679
# explicit        99.953069
# duration-ms     99.953069
# tempo           99.953069
# loudness        99.953069
# energy          99.953069
# danceability    99.953069
# dtype: float64

# %%
df.describe()
# Out:
#        current_week      peak_pos  wks_on_chart    duration-ms       tempo  \
# count  27700.000000  27700.000000  27700.000000      13.000000   13.000000
# mean      50.499964     33.743755     12.315993  179852.307692  122.019077
# std       28.866631     28.010730     11.774950   41805.819921   33.241902
# min        1.000000      1.000000      1.000000  126266.000000   67.086000
# 25%       25.750000      9.000000      3.000000  151933.000000  107.682000
# 50%       50.500000     27.000000      9.000000  182160.000000  116.971000
# 75%       75.250000     55.000000     17.000000  196652.000000  140.453000
# max      100.000000    100.000000     91.000000  262960.000000  201.629000
#
#         loudness     energy  danceability
# count  13.000000  13.000000     13.000000
# mean   -7.507077   0.571538      0.615385
# std     2.907092   0.185004      0.183109
# min   -13.056000   0.327000      0.240000
# 25%    -8.463000   0.424000      0.501000
# ...

# %%
df.describe(include="O")
# Out:
#        chart_week       title      performer last_week  \
# count       27700       27700          27700     25884
# unique        277        3447           1796       101
# top      1/4/2020  Heat Waves  Morgan Wallen         -
# freq          100          91            712      2472
#
#                                 genre(s) explicit
# count                                 12       13
# unique                                12        2
# top     dance pop,pop,urban contemporary    False
# freq                                   1       11

# %% [markdown]
# ### **start API connection**

# %%
# devTools connection
headers = {
    "accept": "*/*",
    "accept-language": "en-Latn-US,en-US;q=0.9,en-Latn;q=0.8,en;q=0.7",
    "authorization": "Bearer BQA_Aw4fcmAFAPGZiKp95grlU8AExmmTqAw59ul6Yb42biYLKakUL7LFC28BF2DNH7Ay8MC4ATv_trGUq4dgKKFTF8OUi5iVRFC08PoXHTyV8b0LZ-nrhs5TmPBZdO-Yws_IE-0R-AoobQmJH5xsEUVpAkZmuWZsrxSC-qYKllGfC-5xIiEkjgIfRHVwHyDdnvIezdO9YxzmHa6z5A-RQfm18vcvYkBRd5dLxoTXfaOQCJ10bPEq-Gquc3ZdibmDDOt7d9I7kPlBT8VRkTp5241Si89fMIQZlsl-FD-t2XgdsFNgG0rUPbuIS3qIG5J-YkYn2iwsnPWsAbotwtH7sheGWVRWwdc9P7pvndwnTbjRYe1BqmqIgAHcaiW83TVjFw",
    "client-token": "",
    "content-type": "application/json",
    "origin": "https://xpui.app.spotify.com",
    "priority": "u=1, i",
    "referer": "https://xpui.app.spotify.com/",
    "sec-ch-ua": '"Chromium";v="131", "Not_A Brand";v="24"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/131.0.6778.109 Spotify/1.2.53.440 Safari/537.36",
}

#API connection
body = requests.post(
    "https://accounts.spotify.com/api/token",
    headers={
        "Content-Type": "application/x-www-form-urlencoded",
    },
    data={
        "grant_type": "client_credentials",
        "client_id": "c42f9abadf514270b4ac267bf368130a",
        "client_secret": "ff5be27b9d3346d79ac5777240688d3f",
    },
)
data = body.json()

URL_BASE = "https://api.spotify.com/v1/"

# %% [markdown]
# #### new columns that will be added from the data collected

# %%
explicit=[]
duration=[]
genres=[]
tempo=[]
loudness=[]
energy=[]
danceability=[]

# %% [markdown]
# ### **add the new columns to the dataframe**

# %%
df['genre(s)']=pd.NA
df['explicit']=pd.NA
df['duration-ms']= pd.NA
df['tempo']=pd.NA
df['loudness']=pd.NA
df['energy']=pd.NA
df['danceability']=pd.NA

# %%
songCache={}
artistCache={}

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27700, step=1)

# %%
df.columns
# Out:
# Index(['chart_week', 'current_week', 'title', 'performer', 'last_week',
#        'peak_pos', 'wks_on_chart', 'genre(s)', 'explicit', 'duration-ms',
#        'tempo', 'loudness', 'energy', 'danceability'],
#       dtype='object')

# %% [markdown]
# ### **get each track's title from base dataset to collect data for the additional columns added**

# %%
x=0
#iterating through each song in the dataset
for idx, row in df.iterrows():
    title=row['title']
    performer=row['performer']
    x=x+1
    
    if pd.isnull(row.explicit)==False:
        continue
    
    
    #check cache first 
    if f"{title} {performer}" in songCache:
        df.loc[idx, "explicit"] =songCache[title][performer]['explicit']
        df.loc[idx, "duration-ms"] =songCache[title][performer]['duration_ms']
        df.loc[idx, "tempo"] =songCache[title][performer]['tempo']
        df.loc[idx, "loudness"] =songCache[title][performer]['loudness']
        df.loc[idx, "energy"] =songCache[title][performer]['energy']
        df.loc[idx, "danceability"] =songCache[title][performer]['danceability']
        df.loc[idx, "genre(s)"] =songCache[title][performer]['genres']
        df.to_csv("billboard 2020-2025.csv",index=None)
        continue
    

    #general search
    resp = requests.get(
        f"{URL_BASE}search",
        params={"q": f'{title} {performer}', "type": "track", "limit": 1},
        headers=headers,   
    )

    genData = resp.json()

    ##assigning data from what is collected
    df.loc[idx, "explicit"]=genData['tracks']['items'][0]['explicit']
    df.loc[idx, "duration-ms"]=genData['tracks']['items'][0]['duration_ms']

    #get artist and track ID for further processing
    artistID=genData['tracks']['items'][0]['artists'][0]['id']
    trackID=genData['tracks']['items'][0]['id']


    #collecting track data
    response = requests.get(
        f"https://api.spotify.com/v1/audio-features/{trackID}", headers=headers
    )

    trackData = response.json()

    #assigning track information
    df.loc[idx, "tempo"]=trackData['tempo']
    df.loc[idx, "loudness"]=trackData['loudness']
    df.loc[idx, "energy"]=trackData['energy']
    df.loc[idx, "danceability"]=trackData['danceability']

    if f'{performer}'in artistCache:
        df.loc[idx, "genre(s)"]=songCache[title][performer]['genres']
        df.to_csv("billboard 2020-2025.csv",index=None)
        continue

    #get info from artist
    resp = requests.get(
        f"{URL_BASE}artists/{artistID}",
        headers={"Authorization": "Bearer " + data["access_token"]},   
    )
    
    artistData = resp.json()

    #assigning artist information
    df.loc[idx, "genre(s)"]=','.join(artistData['genres'])
    
    df.to_csv("billboard 2020-2025.csv",index=None)

    if x%100==0:
       print(x)
# Out:
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 62
#      59     continue
#      61 #get info from artist
# ---> 62 resp = requests.get(
#      63     f"{URL_BASE}artists/{artistID}",
#      64     headers={"Authorization": "Bearer " + data["access_token"]},
#      65 )
#      67 artistData = resp.json()
#      69 #assigning artist information
#
# File c:\Users\Zeina\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Zeina\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
# ...

# %%
df
# Out:
#       chart_week  current_week                              title  \
# 0       1/4/2020             1    All I Want For Christmas Is You
# 1       1/4/2020             2  Rockin' Around The Christmas Tree
# 2       1/4/2020             3                   Jingle Bell Rock
# 3       1/4/2020             4            A Holly Jolly Christmas
# 4       1/4/2020             5                            Circles
# ...          ...           ...                                ...
# 27695  1/11/2025            96                        Holy Smokes
# 27696  1/11/2025            97                          High Road
# 27697  1/11/2025            98                     On One Tonight
# 27698  1/11/2025            99                         St. Chroma
# 27699  1/11/2025           100                       Cowboy Songs
#
#                                         performer last_week  peak_pos  \
# 0                                    Mariah Carey         1         1
# ...
